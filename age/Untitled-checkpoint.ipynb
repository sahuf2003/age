# %%
from keras.models import load_model
from PIL import Image
import numpy as np
import cv2

#the following are to do with this interactive notebook code

# %matplotlib inline 
from matplotlib import pyplot as plt # this lets you draw inline pictures in the notebooks
import pylab # this allows you to control figure size 
pylab.rcParams['figure.figsize'] = (10.0, 8.0) # this controls figure size in the notebook

# %%
from tensorflow.keras.models import load_model

# Load the trained model
model = load_model('age_model_pretrained.h5')

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Now the model is compiled and ready for use
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 198, 198, 32)        │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ average_pooling2d (AveragePooling2D) │ (None, 99, 99, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 97, 97, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ average_pooling2d_1                  │ (None, 48, 48, 64)          │               0 │
# ...

# %%
age_ranges = ['1-2', '3-9', '10-20', '21-27', '28-45', '46-65', '66-116']

# %%
img_path = "sahuf.jpg"

# %%
from IPython.display import Image 
pil_img = Image(filename=img_path)
display(pil_img)

# %%
test_image = cv2.imread(img_path)
gray = cv2.cvtColor(test_image,cv2.COLOR_BGR2GRAY)
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
faces = face_cascade.detectMultiScale(gray, 1.3, 5)

i = 0

for (x,y,w,h) in faces:
  i = i+1
  cv2.rectangle(test_image,(x,y),(x+w,y+h),(203,12,255),2)

  img_gray=gray[y:y+h,x:x+w]

  age_image=cv2.resize(img_gray, (200, 200), interpolation = cv2.INTER_AREA)
  age_input = age_image.reshape(-1, 200, 200, 1)
  output_age = age_ranges[np.argmax(model.predict(age_input))]


  output_str = str(i) + ": "+  output_age
  print(output_str)
  
  col = (0,255,0)

  cv2.putText(test_image, str(i),(x,y),cv2.FONT_HERSHEY_SIMPLEX,1,col,2)

plt.imshow(cv2.cvtColor(test_image, cv2.COLOR_BGR2RGB))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1: 28-45

# %%
img_path = "sahuf.jpg"
pil_img = Image(filename=img_path)
display(pil_img)

test_image = cv2.imread(img_path)
gray = cv2.cvtColor(test_image,cv2.COLOR_BGR2GRAY)
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
faces = face_cascade.detectMultiScale(gray, 1.3, 5)

i = 0

for (x,y,w,h) in faces:
  i = i+1
  cv2.rectangle(test_image,(x,y),(x+w,y+h),(203,12,255),2)

  img_gray=gray[y:y+h,x:x+w]

  age_image=cv2.resize(img_gray, (200, 200), interpolation = cv2.INTER_AREA)
  age_input = age_image.reshape(-1, 200, 200, 1)
  output_age = age_ranges[np.argmax(model.predict(age_input))]


  output_str = str(i) + ": "+  output_age
  print(output_str)
  
  col = (0,255,0)

  cv2.putText(test_image, str(i),(x,y),cv2.FONT_HERSHEY_SIMPLEX,1,col,2)

plt.imshow(cv2.cvtColor(test_image, cv2.COLOR_BGR2RGB))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1: 28-45

# %%
img = "sheldon.jpg"
image = Image(filename=img)
display(image)

test_image = cv2.imread(image)
gray = cv2.cvtColor(test_image,cv2.COLOR_BGR2GRAY)
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
faces = face_cascade.detectMultiScale(gray, 1.3, 5)

i = 0

for (x,y,w,h) in faces:
  i = i+1
  cv2.rectangle(test_image,(x,y),(x+w,y+h),(203,12,255),2)

  img_gray=gray[y:y+h,x:x+w]

  age_image=cv2.resize(img_gray, (200, 200), interpolation = cv2.INTER_AREA)
  age_input = age_image.reshape(-1, 200, 200, 1)
  output_age = age_ranges[np.argmax(model.predict(age_input))]


  output_str = str(i) + ": "+  output_age
  print(output_str)
  
  col = (0,255,0)

  cv2.putText(test_image, str(i),(x,y),cv2.FONT_HERSHEY_SIMPLEX,1,col,2)

plt.imshow(cv2.cvtColor(test_image, cv2.COLOR_BGR2RGB))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 5
#       2 image = Image(filename=img)
#       3 display(image)
# ----> 5 test_image = cv2.imread(image)
#       6 gray = cv2.cvtColor(test_image,cv2.COLOR_BGR2GRAY)
#       7 face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
#
# TypeError: Can't convert object to 'str' for 'filename'

# %%
import cv2
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# Load the image using PIL
img_path = "sahuf.jpg"
pil_img = Image.open(img_path)

# Display the original image
plt.imshow(pil_img)
plt.axis('off')  # Hide axis
plt.show()

# Read the image using OpenCV
test_image = cv2.imread(img_path)
gray = cv2.cvtColor(test_image, cv2.COLOR_BGR2GRAY)

# Load the Haar cascade classifier for face detection
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
faces = face_cascade.detectMultiScale(gray, 1.3, 5)

# Define age ranges (assuming it's defined somewhere in your code)
age_ranges = ["Child", "Teenager", "Young adult", "Adult", "Middle-aged", "Senior"]

# Process each detected face
for i, (x, y, w, h) in enumerate(faces, 1):
    # Draw rectangle around the face
    cv2.rectangle(test_image, (x, y), (x+w, y+h), (203, 12, 255), 2)
    
    # Crop the face region and resize for age prediction
    img_gray = gray[y:y+h, x:x+w]
    age_image = cv2.resize(img_gray, (200, 200), interpolation=cv2.INTER_AREA)
    age_input = age_image.reshape(-1, 200, 200, 1)
    
    # Predict the age using the pre-trained model and display the prediction
    output_age = age_ranges[np.argmax(model.predict(age_input))]
    output_str = f"{i}: {output_age}"
    print(output_str)
    cv2.putText(test_image, output_str, (x, y), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

# Display the image with detected faces and age predictions
plt.imshow(cv2.cvtColor(test_image, cv2.COLOR_BGR2RGB))
plt.axis('off')  # Hide axis
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1: Middle-aged

# %%
import cv2
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# Load the image using PIL
img_path = "sheldon.jpg"
pil_img = Image.open(img_path)

# Display the original image
plt.imshow(pil_img)
plt.axis('off')  # Hide axis
plt.show()

# Read the image using OpenCV
test_image = cv2.imread(img_path)
gray = cv2.cvtColor(test_image, cv2.COLOR_BGR2GRAY)

# Load the Haar cascade classifier for face detection
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
faces = face_cascade.detectMultiScale(gray, 1.3, 5)

# Define age ranges (assuming it's defined somewhere in your code)
age_ranges = ["Child", "Teenager", "Young adult", "Adult", "Middle-aged", "Senior"]

# Process each detected face
for i, (x, y, w, h) in enumerate(faces, 1):
    # Draw rectangle around the face
    cv2.rectangle(test_image, (x, y), (x+w, y+h), (203, 12, 255), 2)
    
    # Crop the face region and resize for age prediction
    img_gray = gray[y:y+h, x:x+w]
    age_image = cv2.resize(img_gray, (200, 200), interpolation=cv2.INTER_AREA)
    age_input = age_image.reshape(-1, 200, 200, 1)
    
    # Predict the age using the pre-trained model and display the prediction
    output_age = age_ranges[np.argmax(model.predict(age_input))]
    output_str = f"{i}: {output_age}"
    print(output_str)
    cv2.putText(test_image, output_str, (x, y), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

# Display the image with detected faces and age predictions
plt.imshow(cv2.cvtColor(test_image, cv2.COLOR_BGR2RGB))
plt.axis('off')  # Hide axis
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1: Teenager

# %%
import cv2
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# Load the image using PIL
img_path = "selena.jpg"
pil_img = Image.open(img_path)

# Display the original image
plt.imshow(pil_img)
plt.axis('off')  # Hide axis
plt.show()

# Read the image using OpenCV
test_image = cv2.imread(img_path)
gray = cv2.cvtColor(test_image, cv2.COLOR_BGR2GRAY)

# Load the Haar cascade classifier for face detection
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
faces = face_cascade.detectMultiScale(gray, 1.3, 5)

# Define age ranges (assuming it's defined somewhere in your code)
age_ranges = ["Child", "Teenager", "Young adult", "Adult", "Middle-aged", "Senior"]

# Process each detected face
for i, (x, y, w, h) in enumerate(faces, 1):
    # Draw rectangle around the face
    cv2.rectangle(test_image, (x, y), (x+w, y+h), (203, 12, 255), 2)
    
    # Crop the face region and resize for age prediction
    img_gray = gray[y:y+h, x:x+w]
    age_image = cv2.resize(img_gray, (200, 200), interpolation=cv2.INTER_AREA)
    age_input = age_image.reshape(-1, 200, 200, 1)
    
    # Predict the age using the pre-trained model and display the prediction
    output_age = age_ranges[np.argmax(model.predict(age_input))]
    output_str = f"{i}: {output_age}"
    print(output_str)
    cv2.putText(test_image, output_str, (x, y), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

# Display the image with detected faces and age predictions
plt.imshow(cv2.cvtColor(test_image, cv2.COLOR_BGR2RGB))
plt.axis('off')  # Hide axis
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[25], line 8
#       6 # Load the image using PIL
#       7 img_path = "selena.jpeg"
# ----> 8 pil_img = Image.open(img_path)
#      10 # Display the original image
#      11 plt.imshow(pil_img)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\PIL\Image.py:3218, in open(fp, mode, formats)
#    3215     filename = fp
#    3217 if filename:
# -> 3218     fp = builtins.open(filename, "rb")
#    3219     exclusive_fp = True
#    3221 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'selena.jpeg'
